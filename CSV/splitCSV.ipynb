# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import os

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV

# %%
columnNames = list()
for i in range(1024):
    pixel = 'pixel'
    pixel += str(i)
    columnNames.append(pixel)

X_train = pd.DataFrame(columns = columnNames)
y_train = pd.DataFrame(columns = ['label'])

X_test = pd.DataFrame(columns = columnNames)
y_test = pd.DataFrame(columns = ['label'])

# %%
ext = ".csv"
for i in range (1,30): #29 letters
    trainFile = cwd + "\\char_" + str(i) + ext
    print(trainFile)
    labelFile = cwd + "\\charLabels_" + str(i) + ext
    print(labelFile)
    X = pd.read_csv(trainFile)
    y = pd.read_csv(labelFile)
    tempX_train, tempX_test, tempy_train, tempy_test = train_test_split(X, y,test_size=0.2)
    X_train = X_train.append(tempX_train, ignore_index = True) 
    y_train = y_train.append(tempy_train, ignore_index = True)
    X_test = X_test.append(tempX_test, ignore_index = True)
    y_test = y_test.append(tempy_test, ignore_index = True)
    print(tempX_train.shape)
    print(X_train.shape)
    print(tempy_train.shape)
    print(y_train.shape)
    print(tempX_test.shape)
    print(X_test.shape)
    print(tempy_test.shape)
    print(y_test.shape)
# Out:
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_1.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_1.csv
# (2192, 1024)
# (2192, 1024)
# (2192, 1)
# (2192, 1)
# (549, 1024)
# (549, 1024)
# (549, 1)
# (549, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_2.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_2.csv
# (1439, 1024)
# (3631, 1024)
# (1439, 1)
# (3631, 1)
# (360, 1024)
# (909, 1024)
# (360, 1)
# (909, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_3.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_3.csv
# (1436, 1024)
# (5067, 1024)
# (1436, 1)
# (5067, 1)
# (360, 1024)
# (1269, 1024)
# (360, 1)
# (1269, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_4.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_4.csv
# (1461, 1024)
# (6528, 1024)
# (1461, 1)
# (6528, 1)
# (366, 1024)
# (1635, 1024)
# (366, 1)
# (1635, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_5.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_5.csv
# (1485, 1024)
# (8013, 1024)
# (1485, 1)
# (8013, 1)
# (372, 1024)
# (2007, 1024)
# (372, 1)
# (2007, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_6.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_6.csv
# (1475, 1024)
# (9488, 1024)
# (1475, 1)
# (9488, 1)
# (369, 1024)
# (2376, 1024)
# (369, 1)
# (2376, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_7.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_7.csv
# (1476, 1024)
# (10964, 1024)
# (1476, 1)
# (10964, 1)
# (370, 1024)
# (2746, 1024)
# (370, 1)
# (2746, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_8.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_8.csv
# (709, 1024)
# (11673, 1024)
# (709, 1)
# (11673, 1)
# (178, 1024)
# (2924, 1024)
# (178, 1)
# (2924, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_9.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_9.csv
# (683, 1024)
# (12356, 1024)
# (683, 1)
# (12356, 1)
# (171, 1024)
# (3095, 1024)
# (171, 1)
# (3095, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_10.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_10.csv
# (677, 1024)
# (13033, 1024)
# (677, 1)
# (13033, 1)
# (170, 1024)
# (3265, 1024)
# (170, 1)
# (3265, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_11.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_11.csv
# (688, 1024)
# (13721, 1024)
# (688, 1)
# (13721, 1)
# (172, 1024)
# (3437, 1024)
# (172, 1)
# (3437, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_12.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_12.csv
# (1383, 1024)
# (15104, 1024)
# (1383, 1)
# (15104, 1)
# (346, 1024)
# (3783, 1024)
# (346, 1)
# (3783, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_13.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_13.csv
# (1365, 1024)
# (16469, 1024)
# (1365, 1)
# (16469, 1)
# (342, 1024)
# (4125, 1024)
# (342, 1)
# (4125, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_14.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_14.csv
# (1378, 1024)
# (17847, 1024)
# (1378, 1)
# (17847, 1)
# (345, 1024)
# (4470, 1024)
# (345, 1)
# (4470, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_15.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_15.csv
# (1354, 1024)
# (19201, 1024)
# (1354, 1)
# (19201, 1)
# (339, 1024)
# (4809, 1024)
# (339, 1)
# (4809, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_16.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_16.csv
# (1402, 1024)
# (20603, 1024)
# (1402, 1)
# (20603, 1)
# (351, 1024)
# (5160, 1024)
# (351, 1)
# (5160, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_17.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_17.csv
# (1364, 1024)
# (21967, 1024)
# (1364, 1)
# (21967, 1)
# (342, 1024)
# (5502, 1024)
# (342, 1)
# (5502, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_18.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_18.csv
# (1388, 1024)
# (23355, 1024)
# (1388, 1)
# (23355, 1)
# (348, 1024)
# (5850, 1024)
# (348, 1)
# (5850, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_19.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_19.csv
# (1376, 1024)
# (24731, 1024)
# (1376, 1)
# (24731, 1)
# (345, 1024)
# (6195, 1024)
# (345, 1)
# (6195, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_20.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_20.csv
# (1385, 1024)
# (26116, 1024)
# (1385, 1)
# (26116, 1)
# (347, 1024)
# (6542, 1024)
# (347, 1)
# (6542, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_21.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_21.csv
# (1393, 1024)
# (27509, 1024)
# (1393, 1)
# (27509, 1)
# (349, 1024)
# (6891, 1024)
# (349, 1)
# (6891, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_22.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_22.csv
# (1388, 1024)
# (28897, 1024)
# (1388, 1)
# (28897, 1)
# (348, 1024)
# (7239, 1024)
# (348, 1)
# (7239, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_23.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_23.csv
# (1400, 1024)
# (30297, 1024)
# (1400, 1)
# (30297, 1)
# (350, 1024)
# (7589, 1024)
# (350, 1)
# (7589, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_24.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_24.csv
# (1380, 1024)
# (31677, 1024)
# (1380, 1)
# (31677, 1)
# (346, 1024)
# (7935, 1024)
# (346, 1)
# (7935, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_25.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_25.csv
# (1422, 1024)
# (33099, 1024)
# (1422, 1)
# (33099, 1)
# (356, 1024)
# (8291, 1024)
# (356, 1)
# (8291, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_26.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_26.csv
# (1387, 1024)
# (34486, 1024)
# (1387, 1)
# (34486, 1)
# (347, 1024)
# (8638, 1024)
# (347, 1)
# (8638, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_27.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_27.csv
# (699, 1024)
# (35185, 1024)
# (699, 1)
# (35185, 1)
# (175, 1024)
# (8813, 1024)
# (175, 1)
# (8813, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_28.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_28.csv
# (1382, 1024)
# (36567, 1024)
# (1382, 1)
# (36567, 1)
# (346, 1024)
# (9159, 1024)
# (346, 1)
# (9159, 1)
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\char_29.csv
# C:\Users\Najwa\Dropbox\BSc\Proposed Ideas\Dataset\CSV\charLabels_29.csv
# (1366, 1024)
# (37933, 1024)
# (1366, 1)
# (37933, 1)
# (342, 1024)
# (9501, 1024)
# (342, 1)
# (9501, 1)

# %%
X_train.to_csv("X_train.csv",index=False)
y_train.to_csv("y_train.csv",index=False)
X_test.to_csv("X_test.csv",index=False)
y_test.to_csv("y_test.csv",index=False)
